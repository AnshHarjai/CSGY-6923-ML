# %%
import pandas as pd

# %%
pip install pyarrow
# Out:
# Requirement already satisfied: pyarrow in /Users/anshharjai/anaconda3/envs/ML/lib/python3.11/site-packages (21.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Install pyarrow for parquet support
# %pip install pyarrow

# Read the parquet file
df = pd.read_parquet('../Dataset/yellow_tripdata_2024-01.parquet')
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1         1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2         1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3         1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4         1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.72         1.0                  N           186            79
# 1           1.80         1.0                  N           140           236
# 2           4.70         1.0                  N           236            79
# 3           1.40         1.0                  N            79           211
# 4           0.80         1.0                  N           211           148
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2         17.7    1.0      0.5        0.00           0.0
# 1             1         10.0    3.5      0.5        3.75           0.0
# 2             1         23.3    3.5      0.5        3.00           0.0
# 3             1         10.0    3.5      0.5        2.00           0.0
# 4             1          7.9    3.5      0.5        3.20           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  Airport_fee
# 0                    1.0         22.70                   2.5          0.0
# 1                    1.0         18.75                   2.5          0.0
# 2                    1.0         31.30                   2.5          0.0
# 3                    1.0         17.00                   2.5          0.0
# 4                    1.0         16.10                   2.5          0.0

# %%
pip install -U ydata-profiling
# Out:
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.17.0-py2.py3-none-any.whl.metadata (22 kB)
# Collecting scipy<1.16,>=1.4.1 (from ydata-profiling)
#   Downloading scipy-1.15.3-cp311-cp311-macosx_14_0_arm64.whl.metadata (61 kB)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.1 in /Users/anshharjai/anaconda3/envs/ML/lib/python3.11/site-packages (from ydata-profiling) (2.3.2)
# Collecting matplotlib<=3.10,>=3.5 (from ydata-profiling)
#   Downloading matplotlib-3.10.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting pydantic>=2 (from ydata-profiling)
#   Downloading pydantic-2.12.3-py3-none-any.whl.metadata (87 kB)
# Collecting PyYAML<6.1,>=5.0.0 (from ydata-profiling)
#   Downloading pyyaml-6.0.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.4 kB)
# Collecting jinja2<3.2,>=2.11.1 (from ydata-profiling)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting visions<0.8.2,>=0.7.5 (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# Collecting numpy<2.2,>=1.16.0 (from ydata-profiling)
#   Using cached numpy-2.1.3-cp311-cp311-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting minify-html>=0.15.0 (from ydata-profiling)
#   Downloading minify_html-0.16.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (18 kB)
# Collecting filetype>=1.0.0 (from ydata-profiling)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting phik<0.13,>=0.11.1 (from ydata-profiling)
#   Downloading phik-0.12.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.6 kB)
# Collecting requests<3,>=2.24.0 (from ydata-profiling)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting tqdm<5,>=4.48.2 (from ydata-profiling)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /Users/anshharjai/anaconda3/envs/ML/lib/python3.11/site-packages (from ydata-profiling) (0.13.2)
# Collecting multimethod<2,>=1.4 (from ydata-profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Collecting statsmodels<1,>=0.13.2 (from ydata-profiling)
#   Downloading statsmodels-0.14.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.5 kB)
# Collecting typeguard<5,>=3 (from ydata-profiling)
#   Downloading typeguard-4.4.4-py3-none-any.whl.metadata (3.3 kB)
# Collecting imagehash==4.3.1 (from ydata-profiling)
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting wordcloud>=1.9.3 (from ydata-profiling)
#   Downloading wordcloud-1.9.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.4 kB)
# Collecting dacite>=1.8 (from ydata-profiling)
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Collecting numba<=0.61,>=0.56.0 (from ydata-profiling)
#   Downloading numba-0.61.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Collecting PyWavelets (from imagehash==4.3.1->ydata-profiling)
#   Downloading pywavelets-1.9.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.6 kB)
# Requirement already satisfied: pillow in /Users/anshharjai/anaconda3/envs/ML/lib/python3.11/site-packages (from imagehash==4.3.1->ydata-profiling) (11.3.0)
# Collecting MarkupSafe>=2.0 (from jinja2<3.2,>=2.11.1->ydata-profiling)
#   Downloading markupsafe-3.0.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/anshharjai/anaconda3/envs/ML/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/anshharjai/anaconda3/envs/ML/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/anshharjai/anaconda3/envs/ML/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/anshharjai/anaconda3/envs/ML/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/anshharjai/anaconda3/envs/ML/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/anshharjai/anaconda3/envs/ML/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/anshharjai/anaconda3/envs/ML/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba<=0.61,>=0.56.0->ydata-profiling)
#   Downloading llvmlite-0.44.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.8 kB)
# Requirement already satisfied: pytz>=2020.1 in /Users/anshharjai/anaconda3/envs/ML/lib/python3.11/site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/anshharjai/anaconda3/envs/ML/lib/python3.11/site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in /Users/anshharjai/anaconda3/envs/ML/lib/python3.11/site-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.5.2)
# Collecting charset_normalizer<4,>=2 (from requests<3,>=2.24.0->ydata-profiling)
#   Downloading charset_normalizer-3.4.4-cp311-cp311-macosx_10_9_universal2.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.24.0->ydata-profiling)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.24.0->ydata-profiling)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.24.0->ydata-profiling)
#   Downloading certifi-2025.10.5-py3-none-any.whl.metadata (2.5 kB)
# Collecting patsy>=0.5.6 (from statsmodels<1,>=0.13.2->ydata-profiling)
#   Downloading patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: typing_extensions>=4.14.0 in /Users/anshharjai/anaconda3/envs/ML/lib/python3.11/site-packages (from typeguard<5,>=3->ydata-profiling) (4.15.0)
# Collecting attrs>=19.3.0 (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting networkx>=2.4 (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting puremagic (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading puremagic-1.30-py3-none-any.whl.metadata (5.8 kB)
# Collecting annotated-types>=0.6.0 (from pydantic>=2->ydata-profiling)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.4 (from pydantic>=2->ydata-profiling)
#   Downloading pydantic_core-2.41.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic>=2->ydata-profiling)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: six>=1.5 in /Users/anshharjai/anaconda3/envs/ML/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)
# Downloading ydata_profiling-4.17.0-py2.py3-none-any.whl (399 kB)
# Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading matplotlib-3.10.0-cp311-cp311-macosx_11_0_arm64.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 38.7 MB/s  0:00:00m0:00:01
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading numba-0.61.0-cp311-cp311-macosx_11_0_arm64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 34.8 MB/s  0:00:00
# Downloading llvmlite-0.44.0-cp311-cp311-macosx_11_0_arm64.whl (26.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.2/26.2 MB 31.1 MB/s  0:00:00m0:00:0100:01
# Using cached numpy-2.1.3-cp311-cp311-macosx_14_0_arm64.whl (5.4 MB)
# Downloading phik-0.12.5-cp311-cp311-macosx_11_0_arm64.whl (665 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 665.5/665.5 kB 22.9 MB/s  0:00:00
# Downloading pyyaml-6.0.3-cp311-cp311-macosx_11_0_arm64.whl (175 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp311-cp311-macosx_10_9_universal2.whl (206 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Downloading scipy-1.15.3-cp311-cp311-macosx_14_0_arm64.whl (22.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.4/22.4 MB 35.7 MB/s  0:00:00m0:00:0100:01
# Downloading statsmodels-0.14.5-cp311-cp311-macosx_11_0_arm64.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 33.3 MB/s  0:00:00 eta 0:00:01
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading typeguard-4.4.4-py3-none-any.whl (34 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading visions-0.8.1-py3-none-any.whl (105 kB)
# Downloading attrs-25.4.0-py3-none-any.whl (67 kB)
# Downloading certifi-2025.10.5-py3-none-any.whl (163 kB)
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading markupsafe-3.0.3-cp311-cp311-macosx_11_0_arm64.whl (12 kB)
# Downloading minify_html-0.16.4-cp311-cp311-macosx_11_0_arm64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 31.2 MB/s  0:00:00
# Downloading networkx-3.5-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 34.0 MB/s  0:00:00
# Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Downloading pydantic-2.12.3-py3-none-any.whl (462 kB)
# Downloading pydantic_core-2.41.4-cp311-cp311-macosx_11_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 33.3 MB/s  0:00:00
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading wordcloud-1.9.4-cp311-cp311-macosx_11_0_arm64.whl (167 kB)
# Downloading puremagic-1.30-py3-none-any.whl (43 kB)
# Downloading pywavelets-1.9.0-cp311-cp311-macosx_11_0_arm64.whl (4.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 28.3 MB/s  0:00:00
# Installing collected packages: puremagic, minify-html, filetype, urllib3, typing-inspection, typeguard, tqdm, PyYAML, pydantic-core, numpy, networkx, multimethod, MarkupSafe, llvmlite, idna, dacite, charset_normalizer, certifi, attrs, annotated-types, scipy, requests, PyWavelets, pydantic, patsy, numba, jinja2, visions, statsmodels, matplotlib, imagehash, wordcloud, phik, ydata-profiling
#   Attempting uninstall: numpy0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  8/34 [pydantic-core]
#     Found existing installation: numpy 2.3.3━━━━━━━━━━━━━━━━━━  8/34 [pydantic-core]
#     Uninstalling numpy-2.3.3:90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  8/34 [pydantic-core]
#       Successfully uninstalled numpy-2.3.3━━━━━━━━━━━━━━━━━━━━  8/34 [pydantic-core]
#   Attempting uninstall: scipy90m╺━━━━━━━━━━━━━━━━━━━━━━━━ 13/34 [llvmlite]]
#     Found existing installation: scipy 1.16.2━━━━━━━━━━━━━━━━━ 13/34 [llvmlite]
#     Uninstalling scipy-1.16.2:━╸━━━━━━━━━━━━━━━━ 20/34 [scipy]
#       Successfully uninstalled scipy-1.16.290m━━━━━━━━━━━━━━━━ 20/34 [scipy]
#   Attempting uninstall: matplotlib━━━━━━╸━━━━━━━ 28/34 [statsmodels]
#     Found existing installation: matplotlib 3.10.6━━━━━━━ 28/34 [statsmodels]
#     Uninstalling matplotlib-3.10.6:━╸━━━━━━━ 28/34 [statsmodels]
#       Successfully uninstalled matplotlib-3.10.690m╺━━━━━ 29/34 [matplotlib]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34/34 [ydata-profiling] [imagehash]]
# Successfully installed MarkupSafe-3.0.3 PyWavelets-1.9.0 PyYAML-6.0.3 annotated-types-0.7.0 attrs-25.4.0 certifi-2025.10.5 charset_normalizer-3.4.4 dacite-1.9.2 filetype-1.2.0 idna-3.11 imagehash-4.3.1 jinja2-3.1.6 llvmlite-0.44.0 matplotlib-3.10.0 minify-html-0.16.4 multimethod-1.12 networkx-3.5 numba-0.61.0 numpy-2.1.3 patsy-1.0.1 phik-0.12.5 puremagic-1.30 pydantic-2.12.3 pydantic-core-2.41.4 requests-2.32.5 scipy-1.15.3 statsmodels-0.14.5 tqdm-4.67.1 typeguard-4.4.4 typing-inspection-0.4.2 urllib3-2.5.0 visions-0.8.1 wordcloud-1.9.4 ydata-profiling-4.17.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Ensure ydata-profiling and numpy are installed
# %pip install -U ydata-profiling

# Import the required module
from ydata_profiling import ProfileReport

# Generate the profiling report
profile = ProfileReport(df, title="YData Profiling Report")

# Display the report in the notebook
profile.to_notebook_iframe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 5
#       1 # Ensure ydata-profiling and numpy are installed
#       2 # %pip install -U ydata-profiling
#       3
#       4 # Import the required module
# ----> 5 from ydata_profiling import ProfileReport
#       7 # Generate the profiling report
#       8 profile = ProfileReport(df, title="YData Profiling Report")
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/ydata_profiling/__init__.py:10
#       6 import warnings  # isort:skip # noqa
#       8 import importlib.util  # isort:skip # noqa
# ---> 10 from ydata_profiling.compare_reports import compare  # isort:skip # noqa
#      11 from ydata_profiling.controller import pandas_decorator  # isort:skip # noqa
#      12 from ydata_profiling.profile_report import ProfileReport  # isort:skip # noqa
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/ydata_profiling/compare_reports.py:12
#      10 from ydata_profiling.model import BaseDescription
#      11 from ydata_profiling.model.alerts import Alert
# ---> 12 from ydata_profiling.profile_report import ProfileReport
#      15 def _should_wrap(v1: Any, v2: Any) -> bool:
#      16     if isinstance(v1, (list, dict)):
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/ydata_profiling/profile_report.py:32
#      30 from ydata_profiling.model import BaseDescription
#      31 from ydata_profiling.model.alerts import AlertType
# ---> 32 from ydata_profiling.model.describe import describe as describe_df
#      33 from ydata_profiling.model.sample import Sample
#      34 from ydata_profiling.model.summarizer import (
#      35     BaseSummarizer,
#      36     ProfilingSummarizer,
#      37     format_summary,
#      38     redact_summary,
#      39 )
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/ydata_profiling/model/describe.py:16
#      11 from ydata_profiling.model.alerts import get_alerts
#      12 from ydata_profiling.model.correlations import (
#      13     calculate_correlation,
#      14     get_active_correlations,
#      15 )
# ---> 16 from ydata_profiling.model.dataframe import preprocess
#      17 from ydata_profiling.model.description import TimeIndexAnalysis
#      18 from ydata_profiling.model.duplicates import get_duplicates
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/ydata_profiling/model/dataframe.py:7
#       4 import pandas as pd
#       6 from ydata_profiling.config import Settings
# ----> 7 from ydata_profiling.model.pandas.dataframe_pandas import pandas_preprocess
#       9 spec = importlib.util.find_spec("pyspark")
#      10 if spec is None:
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/ydata_profiling/model/pandas/__init__.py:27
#      25 # Dynamically import and expose functions from modules
#      26 for module_name in PANDAS_MODULES:
# ---> 27     module = importlib.import_module(f"ydata_profiling.model.pandas.{module_name}")
#      28     globals().update(
#      29         {
#      30             name: getattr(module, name)
#    (...)     33         }
#      34     )
#      36 # Explicitly list exposed names for clarity
#
# File ~/anaconda3/envs/ML/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/ydata_profiling/model/pandas/correlations_pandas.py:8
#       6 import numpy as np
#       7 import pandas as pd
# ----> 8 from scipy import stats
#      10 from ydata_profiling.config import Settings
#      11 from ydata_profiling.model.pandas.discretize_pandas import (
#      12     DiscretizationType,
#      13     Discretizer,
#      14 )
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/scipy/stats/__init__.py:624
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)    619
#     620 """  # noqa: E501
#     622 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     623                                DegenerateDataWarning, FitError)
# --> 624 from ._stats_py import *
#     625 from ._variation import variation
#     626 from .distributions import *
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/scipy/stats/_stats_py.py:38
#      35 import numpy as np
#      36 from numpy import array, asarray, ma
# ---> 38 from scipy import sparse
#      39 from scipy.spatial import distance_matrix
#      41 from scipy.optimize import milp, LinearConstraint
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/scipy/sparse/__init__.py:300
#     294 # Original code by Travis Oliphant.
#     295 # Modified and extended by Ed Schofield, Robert Cimrman,
#     296 # Nathan Bell, and Jake Vanderplas.
#     298 import warnings as _warnings
# --> 300 from ._base import *
#     301 from ._csr import *
#     302 from ._csc import *
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/scipy/sparse/_base.py:5
#       1 """Base class for sparse matrices"""
#       3 import numpy as np
# ----> 5 from ._sputils import (asmatrix, check_reshape_kwargs, check_shape,
#       6                        get_sum_dtype, isdense, isscalarlike,
#       7                        matrix, validateaxis, getdtype)
#       9 from ._matrix import spmatrix
#      11 __all__ = ['isspmatrix', 'issparse', 'sparray',
#      12            'SparseWarning', 'SparseEfficiencyWarning']
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/scipy/sparse/_sputils.py:10
#       8 from math import prod
#       9 import scipy.sparse as sp
# ---> 10 from scipy._lib._util import np_long, np_ulong
#      13 __all__ = ['upcast', 'getdtype', 'getdata', 'isscalarlike', 'isintlike',
#      14            'isshape', 'issequence', 'isdense', 'ismatrix', 'get_sum_dtype',
#      15            'broadcast_shapes']
#      17 supported_dtypes = [np.bool_, np.byte, np.ubyte, np.short, np.ushort, np.intc,
#      18                     np.uintc, np_long, np_ulong, np.longlong, np.ulonglong,
#      19                     np.float32, np.float64, np.longdouble,
#      20                     np.complex64, np.complex128, np.clongdouble]
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/scipy/_lib/_util.py:13
#      10 from typing import TypeAlias, TypeVar
#      12 import numpy as np
# ---> 13 from scipy._lib._array_api import array_namespace, is_numpy, xp_size
#      14 from scipy._lib._docscrape import FunctionDoc, Parameter
#      17 AxisError: type[Exception]
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/scipy/_lib/_array_api.py:18
#      15 import numpy.typing as npt
#      17 from scipy._lib import array_api_compat
# ---> 18 from scipy._lib.array_api_compat import (
#      19     is_array_api_obj,
#      20     size as xp_size,
#      21     numpy as np_compat,
#      22     device as xp_device,
#      23     is_numpy_namespace as is_numpy,
#      24     is_cupy_namespace as is_cupy,
#      25     is_torch_namespace as is_torch,
#      26     is_jax_namespace as is_jax,
#      27     is_array_api_strict_namespace as is_array_api_strict
#      28 )
#      30 __all__ = [
#      31     '_asarray', 'array_namespace', 'assert_almost_equal', 'assert_array_almost_equal',
#      32     'get_xp_devices',
#    (...)     38     'xp_take_along_axis', 'xp_unsupported_param_msg', 'xp_vector_norm',
#      39 ]
#      42 # To enable array API and strict array-like input validation
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/scipy/_lib/array_api_compat/numpy/__init__.py:1
# ----> 1 from numpy import * # noqa: F403
#       3 # from numpy import * doesn't overwrite these builtin names
#       4 from numpy import abs, max, min, round # noqa: F401
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/numpy/testing/__init__.py:11
#       8 from unittest import TestCase
#      10 from . import _private
# ---> 11 from ._private.utils import *
#      12 from ._private.utils import (_assert_valid_refcount, _gen_alignment_data)
#      13 from ._private import extbuild
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/numpy/testing/_private/utils.py:469
#     465         pprint.pprint(desired, msg)
#     466         raise AssertionError(msg.getvalue())
# --> 469 @np._no_nep50_warning()
#     470 def assert_almost_equal(actual, desired, decimal=7, err_msg='', verbose=True):
#     471     """
#     472     Raises an AssertionError if two items are not equal up to desired
#     473     precision.
#    (...)    537
#     538     """
#     539     __tracebackhide__ = True  # Hide traceback for py.test
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/numpy/__init__.py:795, in __getattr__(attr)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# AttributeError: module 'numpy' has no attribute '_no_nep50_warning'
